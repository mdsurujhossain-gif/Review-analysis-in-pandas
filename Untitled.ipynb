# %% [markdown]
# ## ploting average rating / rating count/min rating/max rating by day

# %%
import pandas
from datetime import datetime
import matplotlib.pyplot as plt
from pytz import utc
data = pandas.read_csv('reviews.csv',parse_dates=['Timestamp'])
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %%
data['Day'] = data['Timestamp'].dt.date
##day_count = data.groupby(['Day']).count()
##day_count
day_average = data.groupby(['Day']).mean()
day_average
# Out:
#               Rating
# Day
# 2018-01-01  4.532609
# 2018-01-02  4.122807
# 2018-01-03  4.360465
# 2018-01-04  4.531250
# 2018-01-05  4.423077
# ...              ...
# 2021-03-29  4.240000
# 2021-03-30  4.428571
# 2021-03-31  4.453125
# 2021-04-01  4.592593
# 2021-04-02  4.357143
#
# [1188 rows x 1 columns]

# %%
plt.figure(figsize=(25,3))
plt.plot(day_average.index,day_average['Rating'])
day_average['Rating'].max()
## day_average['Rating'].min()
# Out:
# 5.0

# %% [markdown]
# ## average rating by week

# %%
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U')
week_average = data.groupby(['Week']).mean()
##Week_average
plt.figure(figsize=(25,5))
plt.plot(week_average.index,week_average['Rating'])

# %% [markdown]
# ## downsampling and average rating by month

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
monthly_average = data.groupby(['Month']).mean()
##mohtly average
plt.figure(figsize=(25,5))
plt.plot(monthly_average.index,monthly_average['Rating'])

# %% [markdown]
# ## average rating by month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
monthly_average_course = data.groupby(['Month','Course Name'])['Rating'].mean().unstack()
monthly_average_course.plot(figsize=(25,8))
##monthly_average_course[:20]
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
monthly_average_course
# Out:
# Course Name  100 Python Exercises I: Evaluate and Improve Your Skills  \
# Month
# 2018-01                                               4.353448
# 2018-02                                               4.250000
# 2018-03                                               4.500000
# 2018-04                                               4.431034
# 2018-05                                               4.358696
# 2018-06                                               4.268293
# 2018-07                                               4.589286
# 2018-08                                               4.353659
# 2018-09                                               4.238636
# 2018-10                                               4.106061
# 2018-11                                               4.212766
# 2018-12                                               4.405172
# 2019-01                                               4.048780
# 2019-02                                               4.333333
# ...

# %% [markdown]
# ## what dat people are the happiest

# %%
data['Week_day'] = data['Timestamp'].dt.strftime('%A')
# week_day_average = data.groupby(['Week_day']).mean()
# data
data['Day_number']=data['Timestamp'].dt.strftime('%w')
week_day_average = data.groupby(['Week_day','Day_number']).mean()

week_day_average = week_day_average.sort_values('Day_number')
plt.figure(figsize=(25,4))

plt.plot(week_day_average.index.get_level_values(0),week_day_average['Rating'])
# week_day_average
# week_day_average.plot()
